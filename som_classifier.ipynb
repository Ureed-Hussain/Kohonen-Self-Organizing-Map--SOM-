# %% [markdown]
# # Self-Organizing Map Project Submission
#
# ### Identity of 4 Subjects
#
# Hussain sample 1: **Predicted → Patient**
# Hussain sample 2: **Predicted → Patient**
# Hussain sample 3: **Predicted → Patient**
# Hussain sample 4: **Predicted → Patient**
#
# ---

# %% [markdown]
# # Comparison of Kohonen Network with K-Means and k-Nearest Neighbors (k-NN)
#
# The Kohonen Network, or Self-Organizing Map (SOM), is an unsupervised learning method used mainly for clustering and visualizing high-dimensional data by projecting it onto a lower-dimensional usually 2D grid. Below are the main differences between SOM and two other popular techniques:
#
# ---
#
# **1. Kohonen Network vs. K-Means Clustering**
#
# - **Topology preservation:** SOM tries to preserve the spatial relationships of the input data by organizing similar inputs close to each other on a 2D map. K-Means does not maintain any topological structure, it just assigns data points to the nearest cluster center.
#
# - **Learning mechanism:** SOM uses a competitive learning approach where not only the winning neuron is updated, but also its neighbors based on a neighborhood function. K-Means updates only the cluster centers based on the average of assigned points.
#
# - **Output structure:** SOM produces a structured grid of neurons which can be visualized and interpreted. K-Means gives flat clusters without any spatial layout.
#
# > I read the difference between SOM and K-mean to the following resources:
# > - [K-Means and SOM](https://dzone.com/articles/k-means-and-som-gentle-introduction-to-worlds-most#:~:text=K%2Dmeans%20and%20Kohonen%20SOM,%2C%20they're%20remarkably%20similar.)
# > - A research paper titled [*"Comparative analysis of SOM neural network with K-means clustering algorithm"*](https://ieeexplore.ieee.org/document/5492838), which explains the differences in a very structured and insightful manner.
#
# ---
#
# **2. Kohonen Network vs. k-Nearest Neighbors (k-NN)**
#
# - **Supervision:** SOM is an unsupervised method used during the training phase to organize data. In contrast, k-NN is a **supervised** classification algorithm, it requires labeled data and makes predictions by looking at the closest labeled examples.
#
# - **Usage purpose:** SOM is mainly used for discovering patterns, visualizing data, and clustering. k-NN is used for classifying new data points based on their similarity to existing labeled data.
#
# - **Model structure:** SOM builds a model (a map with weights) through training. k-NN does not build a model in advance, it stores the training data and makes decisions only when a new sample is presented (lazy learning).
#
# > I read this difference in the research paper *"Comparison Between K-Nearest Neighbors, Self-Organizing Maps and Optimum-Path Forest in the Recognition of Packages using Image Analysis by Zernike Moments"* ([IEEE link](https://ieeexplore.ieee.org/document/7059477)).
# > This paper explains in detail how k-NN uses different distance measures and also compares its performance with SOM using image analysis.
#
# ---
# In short, SOM is useful when we want to understand the structure of our data, while K-Means is better for quick clustering, and k-NN is more suitable for classifying new data using known examples.
#
# ---

# %% [markdown]
# ## The following steps outline how I implement, train, and test the Kohonen Self-Organizing Map (SOM) network:

# %% [markdown]
# **Step 1:**
#
# First I Load and combine Control (healthy) and patient data from files, and assigning labels 0 and 1 respectively.

# %%
import numpy as np
# --------- Load Data ---------
def load_data(healthy_path, patient_path):
    healthy_data = np.loadtxt(healthy_path)
    patient_data = np.loadtxt(patient_path)

    # Labels: 0 = healthy, 1 = patient
    data = np.vstack((healthy_data, patient_data))
    labels = np.array([0] * len(healthy_data) + [1] * len(patient_data))


    return data, labels

# %% [markdown]
# **Step 2:**
# I implemented the SOM training by initializing random weights for each neuron and iteratively updating them over multiple epochs. For each input, I calculated the squared Euclidean distance that computed as the sum of squared differences between the input vector and each neuron's weight vector using the formula:
#
# $$
# d = \sum_{i=1}^n (w_i - x_i)^2
# $$
#
# to find the closest neuron (the winner), Then I adjusted the winner's weights to move slightly closer to the input. This process was repeated for all samples and epochs to allow the neurons to self-organize based on the data.

# %%
def train_som(data, num_neurons, learning_rate, epochs):
    # Get the number of features in each input vector
    input_size = data.shape[1]

    # Initialize weight vectors for each neuron with random values
    weights = np.random.rand(num_neurons, input_size)

    # Training loop for the specified number of epochs
    for epoch in range(epochs):
        print(f"\n--- Epoch {epoch + 1} ---")

        # Iterate over each input sample
        for idx, x in enumerate(data):
            # Calculate the squared Euclidean distance from the input to each neuron
            distances = np.sum((weights - x) ** 2, axis=1)

            # Print distances to all neurons just for my understanding
            for i, dist in enumerate(distances):
                print(f"Distance to neuron {i}: {dist:.4f}")

            # Find the index of the closest winning neuron
            winner = np.argmin(distances)
            print(f"Winning neuron: {winner}")

            # Update the weight vector of the winning neuron
            # Move it slightly closer to the input vector
            weights[winner] += learning_rate * (x - weights[winner])

            # Print the updated weights after this sample
            print("Updated weights:")
            print(weights)

    # Return the final trained weight vectors for all neurons
    return weights

# %% [markdown]
# **Step 3:**
# I assigned labels to each neuron by checking which data points were closest to it using squared Euclidean distance. For each neuron, I collected the true labels of the data points it won and then assigned it the most frequent label using majority voting.

# %%
# --------- Assign Labels to Neurons ---------
def label_neurons(weights, data, true_labels):
    assignments = [[] for _ in range(len(weights))]
    for i, x in enumerate(data):
        distances = np.sum((weights - x) ** 2, axis=1)
        winner = np.argmin(distances)
        assignments[winner].append(true_labels[i])

    neuron_labels = []
    for a in assignments:
        if a:
            counts = np.bincount(a)
            neuron_labels.append(np.argmax(counts))
        else:
            neuron_labels.append(-1)
    return neuron_labels

# %% [markdown]
# **Step 4:**
# To make predictions, I used the same squared Euclidean distance formula to find the closest (winning) neuron for each input sample, and returned the label previously assigned to that neuron.

# %%
# --------- Prediction ---------
def predict(x, weights, neuron_labels):
    distances = np.sum((weights - x) ** 2, axis=1)
    winner = np.argmin(distances)
    return neuron_labels[winner]

# %% [markdown]
# **Step 5:**
# In the main section, I first loaded the training data (`control.txt` and `patient.txt`) and trained the SOM using the defined training function. After training, I assigned class labels (Healthy or Patient) to the neurons based on the training data. Then, I loaded my test dataset (`Hussain.txt`) and used the trained weights and labeled neurons to classify each test sample by predicting whether it's Healthy or Patient.

# %% [markdown]
# I used a learning rate of **0.1** and **100 epochs** to train the SOM for more stable and refined weight updates. However, I also tested the network with a **learning rate of 0.5** and **50 epochs**, and it still performed reasonably well. The results were slightly faster to converge but with less precision compared to the lower learning rate setting.

# %%
# --------- MAIN ---------
healthy_path = "control.txt"   #  Upload Training dataset files
patient_path = "patient.txt"

# Load and label data
data, labels = load_data(healthy_path, patient_path)
print(f"Data loaded. Shape: {data.shape}")

# Train SOM
weights = train_som(data, num_neurons=2, learning_rate=0.1, epochs=100)
print("Training complete.")
print("Final Weights", weights)

# Assign neuron labels
neuron_labels = label_neurons(weights, data, labels)
for i, label in enumerate(neuron_labels):
    print(f"Neuron {i} → Class {'Healthy' if label == 0 else 'Patient'}")

# --------- TEST DATA ---------
test_path = "Hussain.txt"  # Upload my dataset
test_data = np.loadtxt(test_path)

print("\n--- Testing on New Data ---")
for i, x in enumerate(test_data):
    prediction = predict(x, weights, neuron_labels)
    label_str = "Healthy" if prediction == 0 else "Patient"
    print(f"Hussain sample {i + 1}: Predicted → {label_str}")
# Out:
# Data loaded. Shape: (20, 650)
#
# --- Epoch 1 ---
# Distance to neuron 0: 2749.5930
# Distance to neuron 1: 2804.7197
# Winning neuron: 0
# Updated weights:
# [[0.53868197 0.38111622 0.55541007 ... 0.52865301 0.70407351 0.32813916]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 2459.7505
# Distance to neuron 1: 2944.0030
# Winning neuron: 0
# Updated weights:
# [[0.48481377 0.3430046  0.49986907 ... 0.47578771 0.63366616 0.29532524]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 2079.5586
# Distance to neuron 1: 2917.2383
# Winning neuron: 0
# Updated weights:
# [[0.43633239 0.30870414 0.44988216 ... 0.42820894 0.57029954 0.26579272]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1793.1850
# Distance to neuron 1: 2947.6186
# Winning neuron: 0
# Updated weights:
# [[0.39269915 0.27783372 0.40489394 ... 0.38538804 0.51326959 0.23921345]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1519.3213
# Distance to neuron 1: 2931.4786
# Winning neuron: 0
# Updated weights:
# [[0.35342924 0.25005035 0.36440455 ... 0.34684924 0.46194263 0.2152921 ]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1343.8558
# Distance to neuron 1: 2882.9867
# Winning neuron: 0
# Updated weights:
# [[0.31808631 0.22504532 0.32796409 ... 0.31216431 0.41574837 0.19376289]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1286.7073
# Distance to neuron 1: 2987.6367
# Winning neuron: 0
# Updated weights:
# [[0.28627768 0.20254078 0.29516769 ... 0.28094788 0.37417353 0.1743866 ]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1060.8986
# Distance to neuron 1: 2919.8646
# Winning neuron: 0
# Updated weights:
# [[0.25764991 0.18228671 0.26565092 ... 0.25285309 0.33675618 0.15694794]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 1060.3461
# Distance to neuron 1: 3139.5634
# Winning neuron: 0
# Updated weights:
# [[0.23188492 0.16405804 0.23908583 ... 0.22756778 0.30308056 0.14125315]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 993.1271
# Distance to neuron 1: 3218.2420
# Winning neuron: 0
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.4546257  0.41956452 0.39608519 ... 0.77682283 0.80430997 0.54212875]]
# Distance to neuron 0: 4682.0878
# Distance to neuron 1: 2707.8867
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.40916313 0.37760807 0.35647667 ... 0.69914054 0.72387897 0.48791588]]
# Distance to neuron 0: 4822.6632
# Distance to neuron 1: 2437.2079
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.36824682 0.33984726 0.320829   ... 0.62922649 0.65149108 0.43912429]]
# Distance to neuron 0: 5004.0821
# Distance to neuron 1: 2229.9874
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.33142213 0.30586253 0.2887461  ... 0.56630384 0.58634197 0.39521186]]
# Distance to neuron 0: 4962.0589
# Distance to neuron 1: 1848.7540
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.29827992 0.27527628 0.25987149 ... 0.50967346 0.52770777 0.35569067]]
# Distance to neuron 0: 4804.8365
# Distance to neuron 1: 1497.7104
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.26845193 0.24774865 0.23388434 ... 0.45870611 0.47493699 0.32012161]]
# Distance to neuron 0: 4740.7286
# Distance to neuron 1: 1303.9586
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.24160674 0.22297379 0.21049591 ... 0.4128355  0.42744329 0.28810945]]
# Distance to neuron 0: 4878.9727
# Distance to neuron 1: 1210.3088
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.21744606 0.20067641 0.18944632 ... 0.37155195 0.38469897 0.2592985 ]]
# Distance to neuron 0: 4669.9887
# Distance to neuron 1: 1032.7116
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.19570146 0.18060877 0.17050169 ... 0.33439676 0.34622907 0.23336865]]
# Distance to neuron 0: 4744.3107
# Distance to neuron 1: 937.0544
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.17613131 0.16254789 0.15345152 ... 0.30095708 0.31160616 0.21003179]]
# Distance to neuron 0: 5015.2673
# Distance to neuron 1: 959.0951
# Winning neuron: 1
# Updated weights:
# [[0.20869643 0.14765223 0.21517724 ... 0.20481101 0.2727725  0.12712783]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
#
# --- Epoch 2 ---
# Distance to neuron 0: 717.4818
# Distance to neuron 1: 4658.7014
# Winning neuron: 0
# Updated weights:
# [[0.18782679 0.13288701 0.19365952 ... 0.18432991 0.24549525 0.11441505]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 756.7801
# Distance to neuron 1: 4810.0698
# Winning neuron: 0
# Updated weights:
# [[0.16904411 0.11959831 0.17429357 ... 0.16589692 0.22094573 0.10297355]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 674.7644
# Distance to neuron 1: 4785.7679
# Winning neuron: 0
# Updated weights:
# [[0.1521397  0.10763848 0.15686421 ... 0.14930722 0.19885116 0.09267619]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 630.0928
# Distance to neuron 1: 4822.6539
# Winning neuron: 0
# Updated weights:
# [[0.13692573 0.09687463 0.14117779 ... 0.1343765  0.17896604 0.08340857]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 597.3393
# Distance to neuron 1: 4806.3803
# Winning neuron: 0
# Updated weights:
# [[0.12323316 0.08718717 0.12706001 ... 0.12093885 0.16106944 0.07506771]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 620.7258
# Distance to neuron 1: 4750.5664
# Winning neuron: 0
# Updated weights:
# [[0.11090984 0.07846845 0.11435401 ... 0.10884497 0.14496249 0.06756094]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 658.8294
# Distance to neuron 1: 4865.3465
# Winning neuron: 0
# Updated weights:
# [[0.09981886 0.0706216  0.10291861 ... 0.09796047 0.13046624 0.06080485]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 557.0909
# Distance to neuron 1: 4802.1729
# Winning neuron: 0
# Updated weights:
# [[0.08983697 0.06355944 0.09262675 ... 0.08816442 0.11741962 0.05472436]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 589.4899
# Distance to neuron 1: 5044.2003
# Winning neuron: 0
# Updated weights:
# [[0.08085327 0.0572035  0.08336407 ... 0.07934798 0.10567766 0.04925193]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 598.5836
# Distance to neuron 1: 5109.9584
# Winning neuron: 0
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.15851818 0.1462931  0.13810637 ... 0.27086137 0.28044555 0.18902861]]
# Distance to neuron 0: 5836.4052
# Distance to neuron 1: 710.1848
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.14266636 0.13166379 0.12429573 ... 0.24377523 0.25240099 0.17012575]]
# Distance to neuron 0: 5987.2809
# Distance to neuron 1: 737.4942
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.12839973 0.11849741 0.11186616 ... 0.21939771 0.22716089 0.15311317]]
# Distance to neuron 0: 6167.7084
# Distance to neuron 1: 750.3485
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.11555975 0.10664767 0.10067954 ... 0.19745794 0.2044448  0.13780186]]
# Distance to neuron 0: 6127.8504
# Distance to neuron 1: 697.1856
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.10400378 0.0959829  0.09061159 ... 0.17771215 0.18400032 0.12402167]]
# Distance to neuron 0: 5967.1511
# Distance to neuron 1: 607.1799
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.0936034  0.08638461 0.08155043 ... 0.15994093 0.16560029 0.1116195 ]]
# Distance to neuron 0: 5903.5186
# Distance to neuron 1: 627.4317
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.08424306 0.07774615 0.07339538 ... 0.14394684 0.14904026 0.10045755]]
# Distance to neuron 0: 6047.6038
# Distance to neuron 1: 587.7737
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.07581875 0.06997154 0.06605585 ... 0.12955215 0.13413624 0.0904118 ]]
# Distance to neuron 0: 5821.9743
# Distance to neuron 1: 586.7447
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.06823688 0.06297438 0.05945026 ... 0.11659694 0.12072261 0.08137062]]
# Distance to neuron 0: 5907.1396
# Distance to neuron 1: 546.0997
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.06141319 0.05667695 0.05350524 ... 0.10493725 0.10865035 0.07323356]]
# Distance to neuron 0: 6181.0540
# Distance to neuron 1: 586.8908
# Winning neuron: 1
# Updated weights:
# [[0.07276795 0.05148315 0.07502767 ... 0.07141318 0.09510989 0.04432673]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
#
# --- Epoch 3 ---
# Distance to neuron 0: 505.1314
# Distance to neuron 1: 5785.2195
# Winning neuron: 0
# Updated weights:
# [[0.06549115 0.04633483 0.0675249  ... 0.06427186 0.0855989  0.03989406]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 564.9155
# Distance to neuron 1: 5940.8017
# Winning neuron: 0
# Updated weights:
# [[0.05894204 0.04170135 0.06077241 ... 0.05784468 0.07703901 0.03590466]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 510.5017
# Distance to neuron 1: 5917.3586
# Winning neuron: 0
# Updated weights:
# [[0.05304783 0.03753122 0.05469517 ... 0.05206021 0.06933511 0.03231419]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 488.2502
# Distance to neuron 1: 5956.5129
# Winning neuron: 0
# Updated weights:
# [[0.04774305 0.03377809 0.04922565 ... 0.04685419 0.0624016  0.02908277]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 489.4632
# Distance to neuron 1: 5940.1927
# Winning neuron: 0
# Updated weights:
# [[0.04296874 0.03040029 0.04430309 ... 0.04216877 0.05616144 0.02617449]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 541.6012
# Distance to neuron 1: 5881.8259
# Winning neuron: 0
# Updated weights:
# [[0.03867187 0.02736026 0.03987278 ... 0.03795189 0.0505453  0.02355704]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 580.0443
# Distance to neuron 1: 6000.1381
# Winning neuron: 0
# Updated weights:
# [[0.03480468 0.02462423 0.0358855  ... 0.0341567  0.04549077 0.02120134]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 494.9394
# Distance to neuron 1: 5938.5679
# Winning neuron: 0
# Updated weights:
# [[0.03132421 0.02216181 0.03229695 ... 0.03074103 0.04094169 0.01908121]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 517.2599
# Distance to neuron 1: 6188.3807
# Winning neuron: 0
# Updated weights:
# [[0.02819179 0.01994563 0.02906725 ... 0.02766693 0.03684752 0.01717309]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 535.4922
# Distance to neuron 1: 6249.6338
# Winning neuron: 0
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.05527187 0.05100925 0.04815471 ... 0.09444352 0.09778532 0.0659102 ]]
# Distance to neuron 0: 6299.2175
# Distance to neuron 1: 493.7038
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.04974468 0.04590833 0.04333924 ... 0.08499917 0.08800678 0.05931918]]
# Distance to neuron 0: 6453.6847
# Distance to neuron 1: 533.7011
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.04477022 0.04131749 0.03900532 ... 0.07649925 0.07920611 0.05338726]]
# Distance to neuron 0: 6633.7665
# Distance to neuron 1: 549.4072
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.04029319 0.03718574 0.03510479 ... 0.06884933 0.07128549 0.04804854]]
# Distance to neuron 0: 6594.6634
# Distance to neuron 1: 550.7899
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.03626387 0.03346717 0.03159431 ... 0.06196439 0.06415695 0.04324368]]
# Distance to neuron 0: 6432.7518
# Distance to neuron 1: 503.3275
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.03263749 0.03012045 0.02843488 ... 0.05576795 0.05774125 0.03891931]]
# Distance to neuron 0: 6369.2850
# Distance to neuron 1: 558.9330
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.02937374 0.02710841 0.02559139 ... 0.05019116 0.05196713 0.03502738]]
# Distance to neuron 0: 6515.4069
# Distance to neuron 1: 506.2964
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.02643636 0.02439757 0.02303225 ... 0.04517204 0.04677041 0.03152464]]
# Distance to neuron 0: 6283.9736
# Distance to neuron 1: 541.0714
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.02379273 0.02195781 0.02072902 ... 0.04065484 0.04209337 0.02837218]]
# Distance to neuron 0: 6372.9197
# Distance to neuron 1: 498.7410
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.02141346 0.01976203 0.01865612 ... 0.03658935 0.03788403 0.02553496]]
# Distance to neuron 0: 6647.8654
# Distance to neuron 1: 529.1679
# Winning neuron: 1
# Updated weights:
# [[0.02537261 0.01795106 0.02616053 ... 0.02490024 0.03316277 0.01545578]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
#
# --- Epoch 4 ---
# Distance to neuron 0: 491.4160
# Distance to neuron 1: 6236.3780
# Winning neuron: 0
# Updated weights:
# [[0.02283535 0.01615596 0.02354448 ... 0.02241021 0.02984649 0.0139102 ]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 546.8810
# Distance to neuron 1: 6393.4294
# Winning neuron: 0
# Updated weights:
# [[0.02055182 0.01454036 0.02119003 ... 0.02016919 0.02686184 0.01251918]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 492.8072
# Distance to neuron 1: 6370.2857
# Winning neuron: 0
# Updated weights:
# [[0.01849664 0.01308633 0.01907103 ... 0.01815227 0.02417566 0.01126726]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 470.8528
# Distance to neuron 1: 6410.2309
# Winning neuron: 0
# Updated weights:
# [[0.01664697 0.01177769 0.01716392 ... 0.01633705 0.02175809 0.01014054]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 477.8177
# Distance to neuron 1: 6393.8945
# Winning neuron: 0
# Updated weights:
# [[0.01498227 0.01059992 0.01544753 ... 0.01470334 0.01958228 0.00912648]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 535.0468
# Distance to neuron 1: 6334.6375
# Winning neuron: 0
# Updated weights:
# [[0.01348405 0.00953993 0.01390278 ... 0.01323301 0.01762405 0.00821383]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 569.6117
# Distance to neuron 1: 6454.1813
# Winning neuron: 0
# Updated weights:
# [[0.01213564 0.00858594 0.0125125  ... 0.01190971 0.01586165 0.00739245]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 487.0693
# Distance to neuron 1: 6393.1702
# Winning neuron: 0
# Updated weights:
# [[0.01092208 0.00772734 0.01126125 ... 0.01071874 0.01427548 0.00665321]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 503.2535
# Distance to neuron 1: 6645.6976
# Winning neuron: 0
# Updated weights:
# [[0.00982987 0.00695461 0.01013513 ... 0.00964686 0.01284794 0.00598788]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 522.5483
# Distance to neuron 1: 6705.3799
# Winning neuron: 0
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01927211 0.01778583 0.01679051 ... 0.03293042 0.03409563 0.02298147]]
# Distance to neuron 0: 6467.9245
# Distance to neuron 1: 476.5874
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.0173449  0.01600724 0.01511146 ... 0.02963738 0.03068607 0.02068332]]
# Distance to neuron 0: 6623.6440
# Distance to neuron 1: 509.9192
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01561041 0.01440652 0.01360031 ... 0.02667364 0.02761746 0.01861499]]
# Distance to neuron 0: 6803.6053
# Distance to neuron 1: 517.6372
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01404937 0.01296587 0.01224028 ... 0.02400628 0.02485572 0.01675349]]
# Distance to neuron 0: 6764.7654
# Distance to neuron 1: 530.7628
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01264443 0.01166928 0.01101625 ... 0.02160565 0.02237014 0.01507814]]
# Distance to neuron 0: 6602.4311
# Distance to neuron 1: 492.2410
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01137999 0.01050235 0.00991463 ... 0.01944508 0.02013313 0.01357033]]
# Distance to neuron 0: 6539.0221
# Distance to neuron 1: 555.3999
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.01024199 0.00945212 0.00892317 ... 0.01750058 0.01811982 0.01221329]]
# Distance to neuron 0: 6685.8541
# Distance to neuron 1: 494.3712
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.00921779 0.00850691 0.00803085 ... 0.01575052 0.01630783 0.01099196]]
# Distance to neuron 0: 6452.3971
# Distance to neuron 1: 538.4983
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.00829601 0.00765621 0.00722776 ... 0.01417547 0.01467705 0.00989277]]
# Distance to neuron 0: 6542.6615
# Distance to neuron 1: 493.0434
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.00746641 0.00689059 0.00650499 ... 0.01275792 0.01320935 0.00890349]]
# Distance to neuron 0: 6817.9668
# Distance to neuron 1: 517.8015
# Winning neuron: 1
# Updated weights:
# [[0.00884688 0.00625915 0.00912161 ... 0.00868218 0.01156314 0.0053891 ]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
#
# --- Epoch 5 ---
# Distance to neuron 0: 493.9681
# Distance to neuron 1: 6400.7831
# Winning neuron: 0
# Updated weights:
# [[0.0079622  0.00563323 0.00820945 ... 0.00781396 0.01040683 0.00485019]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 546.5336
# Distance to neuron 1: 6558.3469
# Winning neuron: 0
# Updated weights:
# [[0.00716598 0.00506991 0.00738851 ... 0.00703256 0.00936615 0.00436517]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 491.4496
# Distance to neuron 1: 6535.3075
# Winning neuron: 0
# Updated weights:
# [[0.00644938 0.00456292 0.00664966 ... 0.00632931 0.00842953 0.00392865]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 468.6845
# Distance to neuron 1: 6575.5286
# Winning neuron: 0
# Updated weights:
# [[0.00580444 0.00410663 0.00598469 ... 0.00569638 0.00758658 0.00353579]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 476.9144
# Distance to neuron 1: 6559.1865
# Winning neuron: 0
# Updated weights:
# [[0.005224   0.00369596 0.00538622 ... 0.00512674 0.00682792 0.00318221]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 535.3187
# Distance to neuron 1: 6499.6191
# Winning neuron: 0
# Updated weights:
# [[0.0047016  0.00332637 0.0048476  ... 0.00461406 0.00614513 0.00286399]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 568.0455
# Distance to neuron 1: 6619.5923
# Winning neuron: 0
# Updated weights:
# [[0.00423144 0.00299373 0.00436284 ... 0.00415266 0.00553062 0.00257759]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 486.0030
# Distance to neuron 1: 6558.7761
# Winning neuron: 0
# Updated weights:
# [[0.00380829 0.00269436 0.00392656 ... 0.00373739 0.00497755 0.00231983]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 499.7289
# Distance to neuron 1: 6812.2501
# Winning neuron: 0
# Updated weights:
# [[0.00342746 0.00242492 0.0035339  ... 0.00336365 0.0044798  0.00208785]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 519.1359
# Distance to neuron 1: 6871.3847
# Winning neuron: 0
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00671977 0.00620153 0.00585449 ... 0.01148213 0.01188841 0.00801314]]
# Distance to neuron 0: 6527.6407
# Distance to neuron 1: 477.7152
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00604779 0.00558138 0.00526904 ... 0.01033391 0.01069957 0.00721183]]
# Distance to neuron 0: 6683.7968
# Distance to neuron 1: 507.3747
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00544301 0.00502324 0.00474214 ... 0.00930052 0.00962961 0.00649064]]
# Distance to neuron 0: 6863.7161
# Distance to neuron 1: 511.2153
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00489871 0.00452092 0.00426792 ... 0.00837047 0.00866665 0.00584158]]
# Distance to neuron 0: 6824.9679
# Distance to neuron 1: 527.5509
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00440884 0.00406883 0.00384113 ... 0.00753342 0.00779999 0.00525742]]
# Distance to neuron 0: 6662.4862
# Distance to neuron 1: 491.4299
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00396796 0.00366194 0.00345702 ... 0.00678008 0.00701999 0.00473168]]
# Distance to neuron 0: 6599.0974
# Distance to neuron 1: 556.6422
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00357116 0.00329575 0.00311132 ... 0.00610207 0.00631799 0.00425851]]
# Distance to neuron 0: 6746.1770
# Distance to neuron 1: 492.2173
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00321404 0.00296617 0.00280018 ... 0.00549187 0.00568619 0.00383266]]
# Distance to neuron 0: 6512.0144
# Distance to neuron 1: 539.2244
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00289264 0.00266956 0.00252017 ... 0.00494268 0.00511757 0.00344939]]
# Distance to neuron 0: 6602.7385
# Distance to neuron 1: 492.3716
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00260338 0.0024026  0.00226815 ... 0.00444841 0.00460581 0.00310446]]
# Distance to neuron 0: 6878.1691
# Distance to neuron 1: 514.9034
# Winning neuron: 1
# Updated weights:
# [[0.00308472 0.00218243 0.00318051 ... 0.00302729 0.00403182 0.00187906]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
#
# --- Epoch 6 ---
# Distance to neuron 0: 495.7496
# Distance to neuron 1: 6458.9703
# Winning neuron: 0
# Updated weights:
# [[0.00277625 0.00196419 0.00286246 ... 0.00272456 0.00362864 0.00169116]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 547.1347
# Distance to neuron 1: 6616.7127
# Winning neuron: 0
# Updated weights:
# [[0.00249862 0.00176777 0.00257621 ... 0.0024521  0.00326577 0.00152204]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 491.5612
# Distance to neuron 1: 6593.7098
# Winning neuron: 0
# Updated weights:
# [[0.00224876 0.00159099 0.00231859 ... 0.00220689 0.0029392  0.00136984]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 468.4023
# Distance to neuron 1: 6634.0270
# Winning neuron: 0
# Updated weights:
# [[0.00202388 0.00143189 0.00208673 ... 0.0019862  0.00264528 0.00123285]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 476.9833
# Distance to neuron 1: 6617.6829
# Winning neuron: 0
# Updated weights:
# [[0.00182149 0.0012887  0.00187806 ... 0.00178758 0.00238075 0.00110957]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 535.7245
# Distance to neuron 1: 6558.0073
# Winning neuron: 0
# Updated weights:
# [[0.00163935 0.00115983 0.00169025 ... 0.00160882 0.00214267 0.00099861]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 567.7512
# Distance to neuron 1: 6678.1302
# Winning neuron: 0
# Updated weights:
# [[0.00147541 0.00104385 0.00152123 ... 0.00144794 0.00192841 0.00089875]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 485.8352
# Distance to neuron 1: 6617.3821
# Winning neuron: 0
# Updated weights:
# [[0.00132787 0.00093946 0.00136911 ... 0.00130315 0.00173557 0.00080887]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 498.6651
# Distance to neuron 1: 6871.1861
# Winning neuron: 0
# Updated weights:
# [[0.00119508 0.00084552 0.00123219 ... 0.00117283 0.00156201 0.00072799]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 518.0799
# Distance to neuron 1: 6930.1297
# Winning neuron: 0
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00234304 0.00216234 0.00204133 ... 0.00400357 0.00414523 0.00279401]]
# Distance to neuron 0: 6548.5708
# Distance to neuron 1: 478.9712
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00210873 0.00194611 0.0018372  ... 0.00360321 0.00373071 0.00251461]]
# Distance to neuron 0: 6704.8792
# Distance to neuron 1: 507.1862
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00189786 0.0017515  0.00165348 ... 0.00324289 0.00335764 0.00226315]]
# Distance to neuron 0: 6884.7838
# Distance to neuron 1: 509.5422
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00170808 0.00157635 0.00148813 ... 0.0029186  0.00302187 0.00203683]]
# Distance to neuron 0: 6846.0677
# Distance to neuron 1: 526.8895
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00153727 0.00141871 0.00133932 ... 0.00262674 0.00271969 0.00183315]]
# Distance to neuron 0: 6683.5346
# Distance to neuron 1: 491.5185
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00138354 0.00127684 0.00120539 ... 0.00236407 0.00244772 0.00164983]]
# Distance to neuron 0: 6620.1528
# Distance to neuron 1: 557.3762
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00124519 0.00114916 0.00108485 ... 0.00212766 0.00220295 0.00148485]]
# Distance to neuron 0: 6767.3188
# Distance to neuron 1: 491.7099
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00112067 0.00103424 0.00097636 ... 0.0019149  0.00198265 0.00133637]]
# Distance to neuron 0: 6532.9101
# Distance to neuron 1: 539.6750
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.0010086  0.00093082 0.00087873 ... 0.00172341 0.00178439 0.00120273]]
# Distance to neuron 0: 6623.7944
# Distance to neuron 1: 492.2972
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00090774 0.00083774 0.00079085 ... 0.00155107 0.00160595 0.00108246]]
# Distance to neuron 0: 6899.2688
# Distance to neuron 1: 514.0223
# Winning neuron: 1
# Updated weights:
# [[0.00107557 0.00076097 0.00110898 ... 0.00105555 0.00140581 0.00065519]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
#
# --- Epoch 7 ---
# Distance to neuron 0: 496.4792
# Distance to neuron 1: 6479.3639
# Winning neuron: 0
# Updated weights:
# [[0.00096802 0.00068487 0.00099808 ... 0.00094999 0.00126523 0.00058967]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 547.4321
# Distance to neuron 1: 6637.1685
# Winning neuron: 0
# Updated weights:
# [[0.00087122 0.00061638 0.00089827 ... 0.000855   0.0011387  0.0005307 ]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 491.6713
# Distance to neuron 1: 6614.1783
# Winning neuron: 0
# Updated weights:
# [[0.00078409 0.00055474 0.00080844 ... 0.0007695  0.00102483 0.00047763]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 468.3616
# Distance to neuron 1: 6654.5290
# Winning neuron: 0
# Updated weights:
# [[0.00070568 0.00049927 0.0007276  ... 0.00069255 0.00092235 0.00042987]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 477.0540
# Distance to neuron 1: 6638.1842
# Winning neuron: 0
# Updated weights:
# [[0.00063512 0.00044934 0.00065484 ... 0.00062329 0.00083012 0.00038688]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 535.9037
# Distance to neuron 1: 6578.4709
# Winning neuron: 0
# Updated weights:
# [[0.0005716  0.00040441 0.00058935 ... 0.00056096 0.0007471  0.00034819]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 567.6792
# Distance to neuron 1: 6698.6460
# Winning neuron: 0
# Updated weights:
# [[0.00051444 0.00036397 0.00053042 ... 0.00050487 0.00067239 0.00031337]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 485.8015
# Distance to neuron 1: 6637.9216
# Winning neuron: 0
# Updated weights:
# [[0.000463   0.00032757 0.00047738 ... 0.00045438 0.00060515 0.00028204]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 498.3143
# Distance to neuron 1: 6891.8407
# Winning neuron: 0
# Updated weights:
# [[0.0004167  0.00029481 0.00042964 ... 0.00040894 0.00054464 0.00025383]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 517.7279
# Distance to neuron 1: 6950.7177
# Winning neuron: 0
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00081697 0.00075396 0.00071177 ... 0.00139596 0.00144535 0.00097421]]
# Distance to neuron 0: 6555.8819
# Distance to neuron 1: 479.5140
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00073527 0.00067857 0.00064059 ... 0.00125636 0.00130082 0.00087679]]
# Distance to neuron 0: 6712.2434
# Distance to neuron 1: 507.2055
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00066174 0.00061071 0.00057653 ... 0.00113073 0.00117074 0.00078911]]
# Distance to neuron 0: 6892.1429
# Distance to neuron 1: 509.0276
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00059557 0.00054964 0.00051888 ... 0.00101765 0.00105366 0.0007102 ]]
# Distance to neuron 0: 6853.4379
# Distance to neuron 1: 526.7146
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00053601 0.00049467 0.00046699 ... 0.00091589 0.0009483  0.00063918]]
# Distance to neuron 0: 6690.8869
# Distance to neuron 1: 491.5945
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00048241 0.00044521 0.00042029 ... 0.0008243  0.00085347 0.00057526]]
# Distance to neuron 0: 6627.5075
# Distance to neuron 1: 557.6686
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00043417 0.00040069 0.00037826 ... 0.00074187 0.00076812 0.00051774]]
# Distance to neuron 0: 6774.7036
# Distance to neuron 1: 491.5626
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00039075 0.00036062 0.00034044 ... 0.00066768 0.00069131 0.00046596]]
# Distance to neuron 0: 6540.2091
# Distance to neuron 1: 539.8561
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00035168 0.00032456 0.00030639 ... 0.00060091 0.00062218 0.00041937]]
# Distance to neuron 0: 6631.1493
# Distance to neuron 1: 492.2908
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00031651 0.0002921  0.00027575 ... 0.00054082 0.00055996 0.00037743]]
# Distance to neuron 0: 6906.6390
# Distance to neuron 1: 513.7309
# Winning neuron: 1
# Updated weights:
# [[0.00037503 0.00026533 0.00038668 ... 0.00036805 0.00049017 0.00022845]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
#
# --- Epoch 8 ---
# Distance to neuron 0: 496.7468
# Distance to neuron 1: 6486.4874
# Winning neuron: 0
# Updated weights:
# [[0.00033753 0.0002388  0.00034801 ... 0.00033124 0.00044116 0.00020561]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 547.5465
# Distance to neuron 1: 6644.3138
# Winning neuron: 0
# Updated weights:
# [[0.00030377 0.00021492 0.00031321 ... 0.00029812 0.00039704 0.00018504]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 491.7183
# Distance to neuron 1: 6621.3280
# Winning neuron: 0
# Updated weights:
# [[0.0002734  0.00019343 0.00028189 ... 0.00026831 0.00035734 0.00016654]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 468.3543
# Distance to neuron 1: 6661.6904
# Winning neuron: 0
# Updated weights:
# [[0.00024606 0.00017408 0.0002537  ... 0.00024148 0.0003216  0.00014989]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 477.0843
# Distance to neuron 1: 6645.3454
# Winning neuron: 0
# Updated weights:
# [[0.00022145 0.00015668 0.00022833 ... 0.00021733 0.00028944 0.0001349 ]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 535.9708
# Distance to neuron 1: 6585.6189
# Winning neuron: 0
# Updated weights:
# [[0.00019931 0.00014101 0.0002055  ... 0.0001956  0.0002605  0.00012141]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 567.6578
# Distance to neuron 1: 6705.8122
# Winning neuron: 0
# Updated weights:
# [[0.00017938 0.00012691 0.00018495 ... 0.00017604 0.00023445 0.00010927]
#  [0.00028486 0.00026289 0.00024818 ... 0.00048674 0.00050396 0.00033969]]
# Distance to neuron 0: 485.7927
# Distance to neuron 1: 6645.0960
# Winning neuron: 0
# Updated weights:
# [[1.61437961e-04 1.14216976e-04 1.66451219e-04 ... 1.58432375e-04
#   2.11004264e-04 9.83402454e-05]
#  [2.84858801e-04 2.62890212e-04 2.48178561e-04 ... 4.86740675e-04
#   5.03963534e-04 3.39686355e-04]]
# Distance to neuron 0: 498.1945
# Distance to neuron 1: 6899.0552
# Winning neuron: 0
# Updated weights:
# [[1.45294165e-04 1.02795278e-04 1.49806097e-04 ... 1.42589138e-04
#   1.89903838e-04 8.85062209e-05]
#  [2.84858801e-04 2.62890212e-04 2.48178561e-04 ... 4.86740675e-04
#   5.03963534e-04 3.39686355e-04]]
# Distance to neuron 0: 517.6072
# Distance to neuron 1: 6957.9090
# Winning neuron: 0
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [2.84858801e-04 2.62890212e-04 2.48178561e-04 ... 4.86740675e-04
#   5.03963534e-04 3.39686355e-04]]
# Distance to neuron 0: 6558.4327
# Distance to neuron 1: 479.7160
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [2.56372921e-04 2.36601190e-04 2.23360704e-04 ... 4.38066607e-04
#   4.53567181e-04 3.05717720e-04]]
# Distance to neuron 0: 6714.8127
# Distance to neuron 1: 507.2225
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [2.30735629e-04 2.12941071e-04 2.01024634e-04 ... 3.94259947e-04
#   4.08210463e-04 2.75145948e-04]]
# Distance to neuron 0: 6894.7104
# Distance to neuron 1: 508.8565
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [2.07662066e-04 1.91646964e-04 1.80922171e-04 ... 3.54833952e-04
#   3.67389416e-04 2.47631353e-04]]
# Distance to neuron 0: 6856.0093
# Distance to neuron 1: 526.6604
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.86895859e-04 1.72482268e-04 1.62829954e-04 ... 3.19350557e-04
#   3.30650475e-04 2.22868218e-04]]
# Distance to neuron 0: 6693.4521
# Distance to neuron 1: 491.6265
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.68206273e-04 1.55234041e-04 1.46546958e-04 ... 2.87415501e-04
#   2.97585427e-04 2.00581396e-04]]
# Distance to neuron 0: 6630.0736
# Distance to neuron 1: 557.7751
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.51385646e-04 1.39710637e-04 1.31892262e-04 ... 2.58673951e-04
#   2.67826885e-04 1.80523256e-04]]
# Distance to neuron 0: 6777.2801
# Distance to neuron 1: 491.5149
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.36247081e-04 1.25739573e-04 1.18703036e-04 ... 2.32806556e-04
#   2.41044196e-04 1.62470931e-04]]
# Distance to neuron 0: 6542.7557
# Distance to neuron 1: 539.9221
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.22622373e-04 1.13165616e-04 1.06832733e-04 ... 2.09525900e-04
#   2.16939776e-04 1.46223838e-04]]
# Distance to neuron 0: 6633.7155
# Distance to neuron 1: 492.2909
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [1.10360136e-04 1.01849054e-04 9.61494593e-05 ... 1.88573310e-04
#   1.95245799e-04 1.31601454e-04]]
# Distance to neuron 0: 6909.2104
# Distance to neuron 1: 513.6312
# Winning neuron: 1
# Updated weights:
# [[1.30764748e-04 9.25157504e-05 1.34825487e-04 ... 1.28330224e-04
#   1.70913454e-04 7.96555988e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
#
# --- Epoch 9 ---
# Distance to neuron 0: 496.8417
# Distance to neuron 1: 6488.9728
# Winning neuron: 0
# Updated weights:
# [[1.17688273e-04 8.32641754e-05 1.21342939e-04 ... 1.15497202e-04
#   1.53822109e-04 7.16900389e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 547.5877
# Distance to neuron 1: 6646.8067
# Winning neuron: 0
# Updated weights:
# [[1.05919446e-04 7.49377578e-05 1.09208645e-04 ... 1.03947481e-04
#   1.38439898e-04 6.45210350e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 491.7358
# Distance to neuron 1: 6623.8224
# Winning neuron: 0
# Updated weights:
# [[9.53275013e-05 6.74439820e-05 9.82877803e-05 ... 9.35527333e-05
#   1.24595908e-04 5.80689315e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 468.3527
# Distance to neuron 1: 6664.1890
# Winning neuron: 0
# Updated weights:
# [[8.57947512e-05 6.06995838e-05 8.84590022e-05 ... 8.41974600e-05
#   1.12136317e-04 5.22620384e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 477.0956
# Distance to neuron 1: 6647.8438
# Winning neuron: 0
# Updated weights:
# [[7.72152761e-05 5.46296255e-05 7.96131020e-05 ... 7.57777140e-05
#   1.00922686e-04 4.70358345e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 535.9948
# Distance to neuron 1: 6588.1128
# Winning neuron: 0
# Updated weights:
# [[6.94937485e-05 4.91666629e-05 7.16517918e-05 ... 6.81999426e-05
#   9.08304170e-05 4.23322511e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 567.6508
# Distance to neuron 1: 6708.3125
# Winning neuron: 0
# Updated weights:
# [[6.25443736e-05 4.42499966e-05 6.44866126e-05 ... 6.13799483e-05
#   8.17473753e-05 3.80990260e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 485.7901
# Distance to neuron 1: 6647.5991
# Winning neuron: 0
# Updated weights:
# [[5.62899363e-05 3.98249970e-05 5.80379514e-05 ... 5.52419535e-05
#   7.35726378e-05 3.42891234e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 498.1529
# Distance to neuron 1: 6901.5723
# Winning neuron: 0
# Updated weights:
# [[5.06609426e-05 3.58424973e-05 5.22341562e-05 ... 4.97177581e-05
#   6.62153740e-05 3.08602110e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 517.5653
# Distance to neuron 1: 6960.4180
# Winning neuron: 0
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [9.93241223e-05 9.16641489e-05 8.65345134e-05 ... 1.69715979e-04
#   1.75721219e-04 1.18441309e-04]]
# Distance to neuron 0: 6559.3223
# Distance to neuron 1: 479.7880
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [8.93917101e-05 8.24977340e-05 7.78810620e-05 ... 1.52744381e-04
#   1.58149097e-04 1.06597178e-04]]
# Distance to neuron 0: 6715.7088
# Distance to neuron 1: 507.2297
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [8.04525391e-05 7.42479606e-05 7.00929558e-05 ... 1.37469943e-04
#   1.42334187e-04 9.59374599e-05]]
# Distance to neuron 0: 6895.6058
# Distance to neuron 1: 508.7979
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [7.24072852e-05 6.68231645e-05 6.30836602e-05 ... 1.23722949e-04
#   1.28100769e-04 8.63437139e-05]]
# Distance to neuron 0: 6856.9061
# Distance to neuron 1: 526.6423
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [6.51665567e-05 6.01408481e-05 5.67752942e-05 ... 1.11350654e-04
#   1.15290692e-04 7.77093425e-05]]
# Distance to neuron 0: 6694.3467
# Distance to neuron 1: 491.6383
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [5.86499010e-05 5.41267633e-05 5.10977648e-05 ... 1.00215589e-04
#   1.03761623e-04 6.99384083e-05]]
# Distance to neuron 0: 6630.9685
# Distance to neuron 1: 557.8127
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [5.27849109e-05 4.87140869e-05 4.59879883e-05 ... 9.01940297e-05
#   9.33854603e-05 6.29445674e-05]]
# Distance to neuron 0: 6778.1787
# Distance to neuron 1: 491.4987
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [4.75064198e-05 4.38426783e-05 4.13891895e-05 ... 8.11746267e-05
#   8.40469143e-05 5.66501107e-05]]
# Distance to neuron 0: 6543.6439
# Distance to neuron 1: 539.9455
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [4.27557778e-05 3.94584104e-05 3.72502705e-05 ... 7.30571641e-05
#   7.56422228e-05 5.09850996e-05]]
# Distance to neuron 0: 6634.6104
# Distance to neuron 1: 492.2912
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [3.84802000e-05 3.55125694e-05 3.35252435e-05 ... 6.57514477e-05
#   6.80780006e-05 4.58865897e-05]]
# Distance to neuron 0: 6910.1072
# Distance to neuron 1: 513.5966
# Winning neuron: 1
# Updated weights:
# [[4.55948484e-05 3.22582475e-05 4.70107406e-05 ... 4.47459823e-05
#   5.95938366e-05 2.77741899e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
#
# --- Epoch 10 ---
# Distance to neuron 0: 496.8750
# Distance to neuron 1: 6489.8395
# Winning neuron: 0
# Updated weights:
# [[4.10353635e-05 2.90324228e-05 4.23096665e-05 ... 4.02713841e-05
#   5.36344529e-05 2.49967709e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 547.6022
# Distance to neuron 1: 6647.6762
# Winning neuron: 0
# Updated weights:
# [[3.69318272e-05 2.61291805e-05 3.80786999e-05 ... 3.62442457e-05
#   4.82710076e-05 2.24970938e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 491.7420
# Distance to neuron 1: 6624.6924
# Winning neuron: 0
# Updated weights:
# [[3.32386445e-05 2.35162625e-05 3.42708299e-05 ... 3.26198211e-05
#   4.34439069e-05 2.02473845e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 468.3522
# Distance to neuron 1: 6665.0603
# Winning neuron: 0
# Updated weights:
# [[2.99147800e-05 2.11646362e-05 3.08437469e-05 ... 2.93578390e-05
#   3.90995162e-05 1.82226460e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 477.0996
# Distance to neuron 1: 6648.7152
# Winning neuron: 0
# Updated weights:
# [[2.69233020e-05 1.90481726e-05 2.77593722e-05 ... 2.64220551e-05
#   3.51895646e-05 1.64003814e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 536.0032
# Distance to neuron 1: 6588.9825
# Winning neuron: 0
# Updated weights:
# [[2.42309718e-05 1.71433553e-05 2.49834350e-05 ... 2.37798496e-05
#   3.16706081e-05 1.47603433e-05]
#  [3.46321800e-05 3.19613124e-05 3.01727191e-05 ... 5.91763029e-05
#   6.12702005e-05 4.12979307e-05]]
# Distance to neuron 0: 567.6484
# Distance to neuron 1: 6709.1844
# Winning neuron: 0
# Updated weights:
# [[2.18078746e-05 1.54290198e-05 2.24850915e-05 ... 2.14018646e-05
# ...
#   3.31632900e-45 2.23530401e-45]]
# Distance to neuron 0: 498.1308
# Distance to neuron 1: 6902.9202
# Winning neuron: 0
# Updated weights:
# [[9.56107373e-46 6.76443708e-46 9.85798118e-46 ... 9.38306961e-46
#   1.24966106e-45 5.82414653e-46]
#  [1.87451162e-45 1.72994745e-45 1.63313752e-45 ... 3.20299407e-45
#   3.31632900e-45 2.23530401e-45]]
# Distance to neuron 0: 517.5430
# Distance to neuron 1: 6961.7615
# Winning neuron: 0
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.87451162e-45 1.72994745e-45 1.63313752e-45 ... 3.20299407e-45
#   3.31632900e-45 2.23530401e-45]]
# Distance to neuron 0: 6559.7986
# Distance to neuron 1: 479.8268
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.68706046e-45 1.55695271e-45 1.46982377e-45 ... 2.88269467e-45
#   2.98469610e-45 2.01177361e-45]]
# Distance to neuron 0: 6716.1885
# Distance to neuron 1: 507.2338
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.51835441e-45 1.40125744e-45 1.32284139e-45 ... 2.59442520e-45
#   2.68622649e-45 1.81059625e-45]]
# Distance to neuron 0: 6896.0852
# Distance to neuron 1: 508.7667
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.36651897e-45 1.26113169e-45 1.19055725e-45 ... 2.33498268e-45
#   2.41760384e-45 1.62953663e-45]]
# Distance to neuron 0: 6857.3862
# Distance to neuron 1: 526.6328
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.22986707e-45 1.13501852e-45 1.07150153e-45 ... 2.10148441e-45
#   2.17584345e-45 1.46658296e-45]]
# Distance to neuron 0: 6694.8256
# Distance to neuron 1: 491.6448
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [1.10688037e-45 1.02151667e-45 9.64351375e-46 ... 1.89133597e-45
#   1.95825911e-45 1.31992467e-45]]
# Distance to neuron 0: 6631.4476
# Distance to neuron 1: 557.8330
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [9.96192330e-46 9.19365004e-46 8.67916237e-46 ... 1.70220237e-45
#   1.76243320e-45 1.18793220e-45]]
# Distance to neuron 0: 6778.6598
# Distance to neuron 1: 491.4901
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [8.96573097e-46 8.27428503e-46 7.81124613e-46 ... 1.53198214e-45
#   1.58618988e-45 1.06913898e-45]]
# Distance to neuron 0: 6544.1194
# Distance to neuron 1: 539.9581
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [8.06915788e-46 7.44685653e-46 7.03012152e-46 ... 1.37878392e-45
#   1.42757089e-45 9.62225082e-46]]
# Distance to neuron 0: 6635.0895
# Distance to neuron 1: 492.2914
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [7.26224209e-46 6.70217088e-46 6.32710937e-46 ... 1.24090553e-45
#   1.28481380e-45 8.66002574e-46]]
# Distance to neuron 0: 6910.5873
# Distance to neuron 1: 513.5782
# Winning neuron: 1
# Updated weights:
# [[8.60496636e-46 6.08799338e-46 8.87218306e-46 ... 8.44476265e-46
#   1.12469495e-45 5.24173187e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
#
# --- Epoch 99 ---
# Distance to neuron 0: 496.8928
# Distance to neuron 1: 6490.3036
# Winning neuron: 0
# Updated weights:
# [[7.74446972e-46 5.47919404e-46 7.98496476e-46 ... 7.60028638e-46
#   1.01222546e-45 4.71755869e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 547.6100
# Distance to neuron 1: 6648.1416
# Winning neuron: 0
# Updated weights:
# [[6.97002275e-46 4.93127463e-46 7.18646828e-46 ... 6.84025775e-46
#   9.11002913e-46 4.24580282e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 491.7453
# Distance to neuron 1: 6625.1582
# Winning neuron: 0
# Updated weights:
# [[6.27302048e-46 4.43814717e-46 6.46782145e-46 ... 6.15623197e-46
#   8.19902622e-46 3.82122254e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 468.3520
# Distance to neuron 1: 6665.5269
# Winning neuron: 0
# Updated weights:
# [[5.64571843e-46 3.99433245e-46 5.82103931e-46 ... 5.54060877e-46
#   7.37912359e-46 3.43910028e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 477.1017
# Distance to neuron 1: 6649.1817
# Winning neuron: 0
# Updated weights:
# [[5.08114659e-46 3.59489921e-46 5.23893538e-46 ... 4.98654790e-46
#   6.64121124e-46 3.09519025e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 536.0077
# Distance to neuron 1: 6589.4482
# Winning neuron: 0
# Updated weights:
# [[4.57303193e-46 3.23540929e-46 4.71504184e-46 ... 4.48789311e-46
#   5.97709011e-46 2.78567123e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 567.6472
# Distance to neuron 1: 6709.6513
# Winning neuron: 0
# Updated weights:
# [[4.11572873e-46 2.91186836e-46 4.24353765e-46 ... 4.03910380e-46
#   5.37938110e-46 2.50710411e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 485.7887
# Distance to neuron 1: 6648.9395
# Winning neuron: 0
# Updated weights:
# [[3.70415586e-46 2.62068152e-46 3.81918389e-46 ... 3.63519342e-46
#   4.84144299e-46 2.25639370e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 498.1308
# Distance to neuron 1: 6902.9202
# Winning neuron: 0
# Updated weights:
# [[3.33374028e-46 2.35861337e-46 3.43726550e-46 ... 3.27167408e-46
#   4.35729869e-46 2.03075433e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 517.5430
# Distance to neuron 1: 6961.7615
# Winning neuron: 0
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [6.53601788e-46 6.03195379e-46 5.69439843e-46 ... 1.11681498e-45
#   1.15633242e-45 7.79402316e-46]]
# Distance to neuron 0: 6559.7986
# Distance to neuron 1: 479.8268
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [5.88241609e-46 5.42875841e-46 5.12495859e-46 ... 1.00513348e-45
#   1.04069918e-45 7.01462085e-46]]
# Distance to neuron 0: 6716.1885
# Distance to neuron 1: 507.2338
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [5.29417448e-46 4.88588257e-46 4.61246273e-46 ... 9.04620132e-46
#   9.36629261e-46 6.31315876e-46]]
# Distance to neuron 0: 6896.0852
# Distance to neuron 1: 508.7667
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [4.76475703e-46 4.39729431e-46 4.15121646e-46 ... 8.14158119e-46
#   8.42966335e-46 5.68184289e-46]]
# Distance to neuron 0: 6857.3862
# Distance to neuron 1: 526.6328
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [4.28828133e-46 3.95756488e-46 3.73609481e-46 ... 7.32742307e-46
#   7.58669702e-46 5.11365860e-46]]
# Distance to neuron 0: 6694.8256
# Distance to neuron 1: 491.6448
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [3.85945320e-46 3.56180839e-46 3.36248533e-46 ... 6.59468076e-46
#   6.82802731e-46 4.60229274e-46]]
# Distance to neuron 0: 6631.4476
# Distance to neuron 1: 557.8330
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [3.47350788e-46 3.20562755e-46 3.02623680e-46 ... 5.93521269e-46
#   6.14522458e-46 4.14206346e-46]]
# Distance to neuron 0: 6778.6598
# Distance to neuron 1: 491.4901
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [3.12615709e-46 2.88506480e-46 2.72361312e-46 ... 5.34169142e-46
#   5.53070212e-46 3.72785712e-46]]
# Distance to neuron 0: 6544.1194
# Distance to neuron 1: 539.9581
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [2.81354138e-46 2.59655832e-46 2.45125181e-46 ... 4.80752228e-46
#   4.97763191e-46 3.35507141e-46]]
# Distance to neuron 0: 6635.0895
# Distance to neuron 1: 492.2914
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [2.53218724e-46 2.33690249e-46 2.20612663e-46 ... 4.32677005e-46
#   4.47986872e-46 3.01956427e-46]]
# Distance to neuron 0: 6910.5873
# Distance to neuron 1: 513.5782
# Winning neuron: 1
# Updated weights:
# [[3.00036625e-46 2.12275203e-46 3.09353895e-46 ... 2.94450667e-46
#   3.92156882e-46 1.82767889e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
#
# --- Epoch 100 ---
# Distance to neuron 0: 496.8928
# Distance to neuron 1: 6490.3036
# Winning neuron: 0
# Updated weights:
# [[2.70032962e-46 1.91047683e-46 2.78418506e-46 ... 2.65005600e-46
#   3.52941194e-46 1.64491100e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 547.6100
# Distance to neuron 1: 6648.1416
# Winning neuron: 0
# Updated weights:
# [[2.43029666e-46 1.71942915e-46 2.50576655e-46 ... 2.38505040e-46
#   3.17647075e-46 1.48041990e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 491.7453
# Distance to neuron 1: 6625.1582
# Winning neuron: 0
# Updated weights:
# [[2.18726699e-46 1.54748623e-46 2.25518989e-46 ... 2.14654536e-46
#   2.85882367e-46 1.33237791e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 468.3520
# Distance to neuron 1: 6665.5269
# Winning neuron: 0
# Updated weights:
# [[1.96854030e-46 1.39273761e-46 2.02967091e-46 ... 1.93189082e-46
#   2.57294130e-46 1.19914012e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 477.1017
# Distance to neuron 1: 6649.1817
# Winning neuron: 0
# Updated weights:
# [[1.77168627e-46 1.25346385e-46 1.82670381e-46 ... 1.73870174e-46
#   2.31564717e-46 1.07922611e-46]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 536.0077
# Distance to neuron 1: 6589.4482
# Winning neuron: 0
# Updated weights:
# [[1.59451764e-46 1.12811746e-46 1.64403343e-46 ... 1.56483157e-46
#   2.08408246e-46 9.71303499e-47]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 567.6472
# Distance to neuron 1: 6709.6513
# Winning neuron: 0
# Updated weights:
# [[1.43506588e-46 1.01530572e-46 1.47963009e-46 ... 1.40834841e-46
#   1.87567421e-46 8.74173149e-47]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 485.7887
# Distance to neuron 1: 6648.9395
# Winning neuron: 0
# Updated weights:
# [[1.29155929e-46 9.13775145e-47 1.33166708e-46 ... 1.26751357e-46
#   1.68810679e-46 7.86755834e-47]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 498.1308
# Distance to neuron 1: 6902.9202
# Winning neuron: 0
# Updated weights:
# [[1.16240336e-46 8.22397631e-47 1.19850037e-46 ... 1.14076221e-46
#   1.51929611e-46 7.08080250e-47]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 517.5430
# Distance to neuron 1: 6961.7615
# Winning neuron: 0
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [2.27896852e-46 2.10321224e-46 1.98551396e-46 ... 3.89409304e-46
#   4.03188185e-46 2.71760784e-46]]
# Distance to neuron 0: 6559.7986
# Distance to neuron 1: 479.8268
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [2.05107167e-46 1.89289101e-46 1.78696257e-46 ... 3.50468374e-46
#   3.62869366e-46 2.44584705e-46]]
# Distance to neuron 0: 6716.1885
# Distance to neuron 1: 507.2338
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.84596450e-46 1.70360191e-46 1.60826631e-46 ... 3.15421536e-46
#   3.26582430e-46 2.20126235e-46]]
# Distance to neuron 0: 6896.0852
# Distance to neuron 1: 508.7667
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.66136805e-46 1.53324172e-46 1.44743968e-46 ... 2.83879383e-46
#   2.93924187e-46 1.98113611e-46]]
# Distance to neuron 0: 6857.3862
# Distance to neuron 1: 526.6328
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.49523125e-46 1.37991755e-46 1.30269571e-46 ... 2.55491445e-46
#   2.64531768e-46 1.78302250e-46]]
# Distance to neuron 0: 6694.8256
# Distance to neuron 1: 491.6448
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.34570812e-46 1.24192579e-46 1.17242614e-46 ... 2.29942300e-46
#   2.38078591e-46 1.60472025e-46]]
# Distance to neuron 0: 6631.4476
# Distance to neuron 1: 557.8330
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.21113731e-46 1.11773321e-46 1.05518353e-46 ... 2.06948070e-46
#   2.14270732e-46 1.44424823e-46]]
# Distance to neuron 0: 6778.6598
# Distance to neuron 1: 491.4901
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [1.09002358e-46 1.00595989e-46 9.49665173e-47 ... 1.86253263e-46
#   1.92843659e-46 1.29982340e-46]]
# Distance to neuron 0: 6544.1194
# Distance to neuron 1: 539.9581
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [9.81021220e-47 9.05363904e-47 8.54698656e-47 ... 1.67627937e-46
#   1.73559293e-46 1.16984106e-46]]
# Distance to neuron 0: 6635.0895
# Distance to neuron 1: 492.2914
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [8.82919098e-47 8.14827514e-47 7.69228790e-47 ... 1.50865143e-46
#   1.56203364e-46 1.05285696e-46]]
# Distance to neuron 0: 6910.5873
# Distance to neuron 1: 513.5782
# Winning neuron: 1
# Updated weights:
# [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [7.94627188e-47 7.33344762e-47 6.92305911e-47 ... 1.35778629e-46
#   1.40583027e-46 9.47571262e-47]]
# Training complete.
# Final Weights [[1.04616302e-46 7.40157868e-47 1.07865034e-46 ... 1.02668599e-46
#   1.36736650e-46 6.37272225e-47]
#  [7.94627188e-47 7.33344762e-47 6.92305911e-47 ... 1.35778629e-46
#   1.40583027e-46 9.47571262e-47]]
# Neuron 0 → Class Healthy
# Neuron 1 → Class Patient
#
# --- Testing on New Data ---
# Hussain sample 1: Predicted → Patient
# Hussain sample 2: Predicted → Patient
# Hussain sample 3: Predicted → Patient
# Hussain sample 4: Predicted → Patient
